# %%
import random
import pandas as pd
from decimal import * 


def createSample(group,sex):
    
    if sex=='M':
        height=random.gauss(178.4,7.6)
        ability1=random.gauss(MEANS[format(prob_men,'.2f')][0],STD_ABILITY1)
        ability2=random.gauss(MEANS[format(prob_men,'.2f')][1],STD_ABILITY2)
        ability1_noise=ability1+random.gauss(0,STD_NOISE)
        ability2_noise=ability2+random.gauss(0,STD_NOISE)
    else:
        height=random.gauss(164.7,7.1)
        ability1=random.gauss(MEANS[format(prob_men+diff_prob, '.2f')][0],STD_ABILITY1)
        ability2=random.gauss(MEANS[format(prob_men+diff_prob, '.2f')][1],STD_ABILITY2)
        ability1_noise=ability1+random.gauss(0,STD_NOISE)
        ability2_noise=ability2+random.gauss(0,STD_NOISE)

    if ability1+ability2>=40:
        label=1
    else:
        label=0
    
    
    sample=[group,numb_dataset,seed,ratio,prob_men,prob_women,diff_prob,ability1_noise,ability2_noise,height,sex,label]
    return sample



#defining factors
RATIO_MEN=[0.5,0.65,0.8,0.95] 
PROB_MEN=[0.05,0.20,0.35,0.5,0.65,0.8,0.95]
DIFF_PROB=[-0.45,-0.30,-0.15,0,0.15,0.30,0.45]
STD_ABILITY1=4
STD_ABILITY2=3
MEANS={'0.05':[20.88,10.88], '0.20':[22.9,12.9], '0.35':[24.035,14.035], '0.50':[25,15], '0.65':[25.965,15.965], '0.80':[27.1,17.1], '0.95':[29.12,19.12]}
STD_NOISE=2.5
NUMBER_DATASETS=550
n=1000



#creating dataset
counter=0
for ratio in RATIO_MEN:
    ratio=round(Decimal(ratio),2)
    for prob_men in PROB_MEN:
        prob_men=round(Decimal(prob_men),2)
        for diff_prob in DIFF_PROB:
            diff_prob=round(Decimal(diff_prob),2)
            if 0<prob_men+diff_prob<1:
                prob_women=round(Decimal(prob_men+diff_prob),2)
                df_list=[]
                for numb_dataset in range(1,NUMBER_DATASETS+1):
                    seed=random.randint(0,10000)
                    random.seed(seed)
                    
                    for number in range(0,2):
                        for i in range(0,int(n*ratio)):
                            df_list.append(createSample(counter+1,'M'))
                        for i in range(0,int(n*(1-ratio))):
                            df_list.append(createSample(counter+1,'F'))

                print('Exp. Group {}'.format(counter+1))
                datasets=pd.DataFrame(df_list,columns=['Exp. Group', '# Dataset', 'Seed', 'Ratio Men', 'Probability Men', 'Probability Women', 'Difference Probabilities','Ability Score 1', 'Ability Score2', 'Height', 'Sex', 'Label'])
                datasets.to_pickle('./Group{}'.format(counter+1))

                counter+=1
# Out:
# Exp. Group 1
# Exp. Group 2
# Exp. Group 3
# Exp. Group 4
# Exp. Group 5
# Exp. Group 6
# Exp. Group 7
# Exp. Group 8
# Exp. Group 9
# Exp. Group 10
# Exp. Group 11
# Exp. Group 12
# Exp. Group 13
# Exp. Group 14
# Exp. Group 15
# Exp. Group 16
# Exp. Group 17
# Exp. Group 18
# Exp. Group 19
# Exp. Group 20
# Exp. Group 21
# Exp. Group 22
# Exp. Group 23
# Exp. Group 24
# Exp. Group 25
# Exp. Group 26
# Exp. Group 27
# Exp. Group 28
# Exp. Group 29
# Exp. Group 30
# Exp. Group 31
# Exp. Group 32
# Exp. Group 33
# Exp. Group 34
# Exp. Group 35
# Exp. Group 36
# Exp. Group 37
# Exp. Group 38
# Exp. Group 39
# Exp. Group 40
# Exp. Group 41
# Exp. Group 42
# Exp. Group 43
# Exp. Group 44
# Exp. Group 45
# Exp. Group 46
# Exp. Group 47
# Exp. Group 48
# Exp. Group 49
# Exp. Group 50
# Exp. Group 51
# Exp. Group 52
# Exp. Group 53
# Exp. Group 54
# Exp. Group 55
# Exp. Group 56
# Exp. Group 57
# Exp. Group 58
# Exp. Group 59
# Exp. Group 60
# Exp. Group 61
# Exp. Group 62
# Exp. Group 63
# Exp. Group 64
# Exp. Group 65
# Exp. Group 66
# Exp. Group 67
# Exp. Group 68
# Exp. Group 69
# Exp. Group 70
# Exp. Group 71
# Exp. Group 72
# Exp. Group 73
# Exp. Group 74
# Exp. Group 75
# Exp. Group 76
# Exp. Group 77
# Exp. Group 78
# Exp. Group 79
# Exp. Group 80
# Exp. Group 81
# Exp. Group 82
# Exp. Group 83
# Exp. Group 84
# Exp. Group 85
# Exp. Group 86
# Exp. Group 87
# Exp. Group 88
# Exp. Group 89
# Exp. Group 90
# Exp. Group 91
# Exp. Group 92
# Exp. Group 93
# Exp. Group 94
# Exp. Group 95
# Exp. Group 96
# Exp. Group 97
# Exp. Group 98
# Exp. Group 99
# Exp. Group 100
# Exp. Group 101
# Exp. Group 102
# Exp. Group 103
# Exp. Group 104
# Exp. Group 105
# Exp. Group 106
# Exp. Group 107
# Exp. Group 108
# Exp. Group 109
# Exp. Group 110
# Exp. Group 111
# Exp. Group 112
# Exp. Group 113
# Exp. Group 114
# Exp. Group 115
# Exp. Group 116
# Exp. Group 117
# Exp. Group 118
# Exp. Group 119
# Exp. Group 120
# Exp. Group 121
# Exp. Group 122
# Exp. Group 123
# Exp. Group 124
# Exp. Group 125
# Exp. Group 126
# Exp. Group 127
# Exp. Group 128
# Exp. Group 129
# Exp. Group 130
# Exp. Group 131
# Exp. Group 132
# Exp. Group 133
# Exp. Group 134
# Exp. Group 135
# Exp. Group 136
# Exp. Group 137
# Exp. Group 138
# Exp. Group 139
# Exp. Group 140
# Exp. Group 141
# Exp. Group 142
# Exp. Group 143
# Exp. Group 144
# Exp. Group 145
# Exp. Group 146
# Exp. Group 147
# Exp. Group 148

# %%
print(datasets.size)
print(datasets.describe())
# Out:
# 1628000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-e06b01cc00dd> in <module>
#       1 print(datasets.size)
# ----> 2 print(datasets.describe())
#
# c:\users\marcel öfele\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in describe(self, percentiles, include, exclude)
#    9802             data = self.select_dtypes(include=include, exclude=exclude)
#    9803
# -> 9804         ldesc = [describe_1d(s) for _, s in data.iteritems()]
#    9805         # set a convenient order for rows
#    9806         names = []
#
# c:\users\marcel öfele\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in <listcomp>(.0)
#    9802             data = self.select_dtypes(include=include, exclude=exclude)
#    9803
# -> 9804         ldesc = [describe_1d(s) for _, s in data.iteritems()]
#    9805         # set a convenient order for rows
#    9806         names = []
#
# c:\users\marcel öfele\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in describe_1d(data)
#    9781                 return describe_categorical_1d(data)
#    9782             elif is_numeric_dtype(data):
# -> 9783                 return describe_numeric_1d(data)
#    9784             elif is_timedelta64_dtype(data):
#    9785                 return describe_numeric_1d(data)
#
# c:\users\marcel öfele\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in describe_numeric_1d(series)
#    9747                           formatted_percentiles + ['max'])
#    9748             d = ([series.count(), series.mean(), series.std(), series.min()] +
# -> 9749                  series.quantile(percentiles).tolist() + [series.max()])
#    9750             return pd.Series(d, index=stat_index, name=series.name)
#    9751
#
# c:\users\marcel öfele\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   10954                                       skipna=skipna)
#   10955         return self._reduce(f, name, axis=axis, skipna=skipna,
# > 10956                             numeric_only=numeric_only)
#   10957
#   10958     return set_function_name(stat_func, name, cls)
#
# c:\users\marcel öfele\appdata\local\programs\python\python36\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3628                                           'numeric_only.'.format(name))
#    3629             with np.errstate(all='ignore'):
# -> 3630                 return op(delegate, skipna=skipna, **kwds)
#    3631
#    3632         # TODO(EA) dispatch to Index
#
# c:\users\marcel öfele\appdata\local\programs\python\python36\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      74             try:
#      75                 with np.errstate(invalid='ignore'):
# ---> 76                     return f(*args, **kwargs)
#      77             except ValueError as e:
#      78                 # we want to transform an object array
#
# c:\users\marcel öfele\appdata\local\programs\python\python36\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     125                         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     126                 else:
# --> 127                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     128             except Exception:
#     129                 try:
#
# c:\users\marcel öfele\appdata\local\programs\python\python36\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna, mask)
#     467     """
#     468     values, mask, dtype, dtype_max, _ = _get_values(
# --> 469         values, skipna, 0, mask=mask)
#     470     dtype_sum = dtype_max
#     471     dtype_count = np.float64
#
# c:\users\marcel öfele\appdata\local\programs\python\python36\lib\site-packages\pandas\core\nanops.py in _get_values(values, skipna, fill_value, fill_value_typ, isfinite, copy, mask)
#     221             mask = _isfinite(values)
#     222         else:
# --> 223             mask = isna(values)
#     224
#     225     if is_datetime_or_timedelta_dtype(values) or is_datetime64tz_dtype(values):
#
# c:\users\marcel öfele\appdata\local\programs\python\python36\lib\site-packages\pandas\core\dtypes\missing.py in isna(obj)
#      97     Name: 1, dtype: bool
#      98     """
# ---> 99     return _isna(obj)
#     100
#     101
#
# c:\users\marcel öfele\appdata\local\programs\python\python36\lib\site-packages\pandas\core\dtypes\missing.py in _isna_new(obj)
#     112                           ABCExtensionArray,
#     113                           ABCDatetimeArray, ABCTimedeltaArray)):
# --> 114         return _isna_ndarraylike(obj)
#     115     elif isinstance(obj, ABCGeneric):
#     116         return obj._constructor(obj._data.isna(func=isna))
#
# c:\users\marcel öfele\appdata\local\programs\python\python36\lib\site-packages\pandas\core\dtypes\missing.py in _isna_ndarraylike(obj)
#     218         result = values.view('i8') == iNaT
#     219     else:
# --> 220         result = np.isnan(values)
#     221
#     222     # box
#
# KeyboardInterrupt:

# %%
datasets.to_pickle('C:/Users/Marcel Öfele/Desktop/datasets.pkl')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-27-8140de51fa2b> in <module>
# ----> 1 datasets.to_pickle('C:/Users/Marcel Öfele/Desktop/datasets.pkl')
#
# c:\users\marcel öfele\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in to_pickle(self, path, compression, protocol)
#    2591         from pandas.io.pickle import to_pickle
#    2592         return to_pickle(self, path, compression=compression,
# -> 2593                          protocol=protocol)
#    2594
#    2595     def to_clipboard(self, excel=True, sep=None, **kwargs):
#
# c:\users\marcel öfele\appdata\local\programs\python\python36\lib\site-packages\pandas\io\pickle.py in to_pickle(obj, path, compression, protocol)
#      75         protocol = pkl.HIGHEST_PROTOCOL
#      76     try:
# ---> 77         f.write(pkl.dumps(obj, protocol=protocol))
#      78     finally:
#      79         for _f in fh:
#
# MemoryError:

# %%
C:\Users\Marcel Öfele\Desktop
